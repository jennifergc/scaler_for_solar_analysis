# %% [markdown]
# ## Timeinverval - Scaler dataframe for Auger Open Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Corrected Data With 'ScalerAnalysis'
# - Data from jan 2006 to jun 2021

# %%
from augerscalerpy.scaler_clear import plotscaler ## ESTA SÍ ESSSSS LA FORMAAAAAAAAAAA!!!!!!!!

# %%
mayo30 = plotscaler('VM_1800s.csv','mayo30')
# Out:
# Hay  (191, 5) líneas vacías

# %%
scalerh= plotscaler('VM_PRUEBA.csv','vm_prueba')
# Out:
# Hay  (367, 5) líneas vacías

# %%
eventoFDU = scalerh[scalerh['Date'] >= "2012-02-01"]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2012-02-03" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',rot=45,figsize=(10, 5),color='black')
plt.show()

# %%
## ______________________ FORBUSH JUNE 2025, VM 900S _____________________________________

# %%
scaler0615 = plotscaler('VM_19marzo.csv')
# Out:
# Hay  (192, 5) líneas vacías

# %%
### PROMEDIO DE VENTANA MÓVIL 
### ____________________________UN DATO CADA HORA

scaler1800s= plotscaler('VM_MOD1800.csv')
# Out:
# Hay  (30, 4) líneas vacías

# %%
### PROMEDIO DE VENTANA MÓVIL 
### ____________________________UN DATO CADA HORA__________ TODOS LOS AÑOS (MEJORAR)

scaler3600s= plotscaler('scaler_ALL_hourly_11abril.csv','abril11')
# Out:
# Hay  (11805, 4) líneas vacías

# %%
scaler3600s = scaler3600s.reset_index(drop=True)

scaler3600s['ScalerCorr'] = scaler3600s['ScalerCorr'].astype(int)
print(scaler3600s)
# Out:
#                       Date  ScalerCorr  pressure  activeSD
# 0      2006-01-01 00:29:46        1603   858.762   544.333
# 1      2006-01-01 00:59:46        1603   859.376   549.250
# 2      2006-01-01 01:29:46        1604   859.990   554.083
# 3      2006-01-01 01:59:46        1606   860.604   558.083
# 4      2006-01-01 02:29:46        1607   861.121   561.833
# ...                    ...         ...       ...       ...
# 225025 2020-12-31 20:59:46        1656   858.720   424.167
# 225026 2020-12-31 21:29:46        1654   858.809   422.500
# 225027 2020-12-31 21:59:46        1654   858.950   421.833
# 225028 2020-12-31 22:29:46        1655   859.195   423.333
# 225029 2020-12-31 22:59:46        1654   859.466   425.083
#
# [225030 rows x 4 columns]

# %% [markdown]
# Comparación Olulu con Auger
# Relación con las líneas de parquer (bibliografía)
# Buscar variación entre picos de horas
# Calcular las líneas de parquer y la frecuencia
# ver si la frecuencia coincide con ~23h
# Consultarle a Ilaria el análisis de los datos (sobre la periodicidad diaria)

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2013-03-1" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2013-03-30" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2013-04-12" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2013-04-30" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=30,figsize=(5, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2013-06-01" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2013-07-10" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2013-12-1" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2013-12-31" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2017-01-01" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2017-01-31" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=45,figsize=(10, 5))
plt.savefig('scaler_2year_daily.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2014-09-01" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2014-09-30" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=30,figsize=(5, 5))
plt.savefig('scaler_201409.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2014-12-10" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <=  "2015-01-10" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=30,figsize=(5, 5))
plt.savefig('scaler_201412.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2015-03-10" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <=  "2015-03-31" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2015-06-01" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <=  "2015-07-10" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2015-12-28" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <=  "2016-01-20" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2017-07-14" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <=  "2017-07-26" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
eventoFDU = tasting300[tasting300['Date'] >= "2019-05-01" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <=  "2019-05-30" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
#MÍNIMO SOLAR 2020 (GRÁFICA DE 'RUIDO ALGO AHÍ QUE NO ENCUENTRO REPORTE')

eventoFDU = tasting300[tasting300['Date'] >= "2020-06-25" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2020-07-08" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='green',rot=45,figsize=(10, 5))
plt.show()

# %% [markdown]
# ## LINGRI COMPARISON

# %%
## LINGRI COMPARISON
eventoFDU = tasting300[tasting300['Date'] >= "2011-02-17" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2011-02-21" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=30,figsize=(5, 5))
plt.savefig('scaler_201102.png')
plt.show()

# %%
## LINGRI COMPARISON (ISN'T POSSIBLE)
eventoFDU = tasting300[tasting300['Date'] >= "2012-03-01" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2012-03-07" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=30,figsize=(5, 5))
plt.savefig('scaler_201008.png')
plt.show()

# %%
## LINGRI COMPARISON
eventoFDU = tasting300[tasting300['Date'] >= "2012-07-13" ]
eventoFDD = eventoFDU[eventoFDU['Date'] <= "2012-07-20" ]
eventoFDD.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',color='black',rot=30,figsize=(5, 5))
plt.savefig('scaler_201207.png')
plt.show()
