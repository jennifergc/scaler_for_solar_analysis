# %%
import pandas as pd
import matplotlib
print(matplotlib.__version__)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from augerscalerpy.scaler_cleaning import scaler_clean, plot_data
from augerscalerpy.plot_config import configure_plots
# Out:
# 3.7.0

# %% [raw]
# import requests
# import pandas as pd
# from io import StringIO
#
# # Crear una lista para almacenar los DataFrames de cada año
# dataframes = []
#
# # Rango de años desde 1957 hasta 2021
# for year in range(1957, 2022):
#     # Construir la URL con el año actual
#     url = f"http://spaceweather.izmiran.ru/dbs/fds/years/{year}.txt"
#
#     # Realizar una solicitud GET a la URL
#     response = requests.get(url)
#
#     # Verificar si la solicitud fue exitosa
#     if response.status_code == 200:
#         # Leer el contenido de la página como una cadena y separar las líneas
#         content = response.text
#         lines = content.split('\n')
#
#         # Crear un DataFrame a partir de las líneas con tabulaciones como separadores
#         df = pd.read_csv(StringIO(content), sep='\t', header=None)
#
#         # Agregar el DataFrame a la lista
#         dataframes.append(df)
#
# # Concatenar todos los DataFrames en uno solo
# df_combined = pd.concat(dataframes)
#
# # Restablecer el índice del DataFrame resultante
# #df_combined.reset_index(drop=True, inplace=True)
# # Ahora df_combined contiene los datos de todos los años en un solo DataFrame de pandas
# df_combined

# %% [raw]
# df_combined.to_csv("forbush_decrease_ALL_years.csv")

# %% [markdown]
# ### Leyendo el archivo que ya está guardado

# %%
data = pd.read_csv('forbush_decrease_ALL_years.csv')
data['MagnM'] = data['MagnM'].apply(lambda x: x if x >= 0 else 0)
data
# Out:
#                     date  MagnM  Axym  Azrange  TminM  DminM  OType   Bmax  \
# 0    1957.07.05 00:42:00    3.8  1.69     3.87     10  -0.81      1 -999.0
# 1    1957.07.06 20:00:00    1.6  1.84     3.92     -2  -0.66      9 -999.0
# 2    1957.07.09 06:00:00    1.4  1.88     4.22      1  -1.07      9 -999.0
# 3    1957.07.11 10:00:00    1.5  1.77     3.45      9  -1.07      9 -999.0
# 4    1957.07.13 19:00:00    1.2  2.63     3.80      8  -0.70      9 -999.0
# ..                   ...    ...   ...      ...    ...    ...    ...    ...
# 104  2020.12.19 09:00:00    0.5  1.05     0.87     11  -0.21      9    9.0
# 105  2020.12.20 23:00:00    0.6  0.86     0.92     19  -0.18      9   11.6
# 106  2020.12.22 01:00:00    0.6  0.82     0.72      6  -0.20      9   12.9
# 107  2020.12.27 04:00:00    0.5  0.59     0.52     42  -0.21      9    7.2
# 108  2020.12.29 18:00:00    0.6  0.98     0.71     16  -0.19      9    6.8
#
#      Bzmin   Vmax  Dstmin
# 0    999.0 -999.0   -92.0
# 1    999.0 -999.0   -45.0
# 2    999.0 -999.0   -12.0
# 3    999.0 -999.0   -12.0
# 4    999.0 -999.0    -2.0
# ..     ...    ...     ...
# 104   -3.3  388.0   -12.0
# 105   -6.5  407.0   -13.0
# 106   -2.4  637.0   -22.0
# 107   -3.0  552.0   -14.0
# 108   -3.4  509.0   -15.0
#
# [7939 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd


# Filtrar el DataFrame para obtener solo los valores de OType 1, 3 y 9
filtered_data = data[data['OType'].isin([1, 2, 3, 9])]
filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')

date_values = filtered_data['date'].values
date_values = pd.to_datetime(date_values)

# Calcula los años a partir de las fechas en 'date_sc'
years = date_values.year

# Extraer los valores de date, MagnM y OType
date_values = filtered_data['date']
MagnM_values = filtered_data['MagnM']
OType_values = filtered_data['OType']

# Crear una figura
plt.figure(figsize=(12, 6))

# Crear un mapa de colores discreto para OType (1, 3 y 9)
#colors = {1: 'blue', 3: 'green', 9: 'red'}
#colors = {1: 'black', 3: 'orange', 9: 'cyan'}
colors = {9: 'cyan',3: 'orange',2: 'darkviolet', 1: 'black',  }
color_values = [colors[otype] for otype in OType_values]

# Crear un mapa de colores personalizado con ListedColormap
#cmap = mcolors.ListedColormap(['blue', 'green', 'red'])
#cmap = mcolors.ListedColormap(['black', 'orange', 'cyan'])
cmap = mcolors.ListedColormap(['cyan','orange', 'darkviolet', 'black'])

# Crear un gráfico de dispersión con mapa de color
scatter = plt.scatter(date_values, MagnM_values,  c=color_values,cmap=cmap, s=20, alpha=0.8)

# Configurar etiquetas y título
plt.xlabel('Years')
plt.ylabel('FD magnitude for particles with 10 GV rigidity')
plt.title('')


# Agregar una barra de color personalizada
#cbar = plt.colorbar(scatter, cmap=cmap , ticks=[1, 3, 9])
#cbar.set_ticks([1, 3, 9])
#cbar.set_ticklabels(['1', '3', '9'])
#cbar.set_label('OType')

# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_24357/1225384244.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')
# /tmp/ipykernel_24357/1225384244.py:36: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = plt.scatter(date_values, MagnM_values,  c=color_values,cmap=cmap, s=20, alpha=0.8)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar el DataFrame para obtener solo los valores de OType 1, 3 y 9
filtered_data = data[data['OType'].isin([1, 3, 9])]
filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')

# Crear un gráfico de densidad (Density Plot)
plt.figure(figsize=(12, 6))
sns.kdeplot(data=filtered_data, x='date', y='MagnM', hue='OType', fill=True, common_norm=False)

# Configurar etiquetas y título
plt.xlabel('Fecha')
plt.ylabel('Magnitud (MagnM)')
plt.title('Gráfico de Densidad de Magnitud vs. Fecha por OType')

# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_24357/3269104094.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import joypy
from joypy import joyplot
import matplotlib.pyplot as plt
from matplotlib import cm

# Filtrar el DataFrame para obtener solo los valores de OType 1, 2, 3 y 9
filtered_data = data[data['OType'].isin([1, 2, 3, 9])]
filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S') #antes
#filtered_data.loc[:, 'date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S') #ahora

# Duplicar las filas para aumentar el espaciado vertical
#filtered_data = pd.concat([filtered_data] * 5, ignore_index=True)


# Crear una figura
plt.figure(figsize=(12, 6))

# Crear un Ridgeline Plot
joyplot(
    data=filtered_data, 
    by=filtered_data['date'].dt.year,  # Agrupa por el año de la columna 'date'
    #by=(filtered_data['date'].dt.year // 2) * 2,  # Agrupa por intervalos de 2 años
    column='MagnM',     # La columna de magnitud
    figsize=(10, 20),    # Tamaño de la figura
    colormap=cm.viridis,  # Mapa de colores
    #colormap=palette,  # Utiliza la paleta de colores
    #color=filtered_data['OType_Color'],  # Utiliza los colores asignados
    x_range=(0, 6),     # Establece el rango en el eje x
    alpha=0.6,          # Transparencia
    overlap=1  # Ajusta el valor de superposición
)


# Configurar etiquetas y título
plt.xlabel('Magnitud (MagnM)')
plt.ylabel('Año')
plt.title('')


# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_24357/517232797.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S') #antes

# %%
import pandas as pd
import joypy
import matplotlib.pyplot as plt

# Filtrar el DataFrame para obtener solo los valores de OType 1, 2, 3 y 9
filtered_data = data[data['OType'].isin([1, 2, 3, 9])]
filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')

# Crear una figura
plt.figure(figsize=(12, 6))

# Crear un Ridgeline Plot
joyplot(
    data=filtered_data,
    figsize=(10, 20),    # Tamaño de la figura
    by=filtered_data['date'].dt.year,
    column='OType',
    x_range=(0, 10),  # Ajustar el rango en el eje X a los valores de OType
    alpha=0.6,
    overlap=1
)

# Configurar etiquetas y título
plt.xlabel('OType')
plt.ylabel('Año')
plt.title('Año vs OType')

# Mostrar el gráfico
plt.show()
# Out:
# /tmp/ipykernel_24357/4195806064.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filtrar el DataFrame para obtener solo los valores de OType 1, 2, 3 y 9
filtered_data = data[data['OType'].isin([1, 2, 3, 9])]

# Crear una figura con un tamaño más grande
plt.figure(figsize=(20, 8))

filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')
filtered_data.loc[:, 'year'] = filtered_data['date'].dt.year

# Agrupar los datos por año y contar la frecuencia de cada valor de OType
grouped = filtered_data.groupby(['year', 'OType']).size().unstack(fill_value=0)
# Crear un gráfico de barras apiladas
grouped.plot(kind='bar', stacked=False)

# Configurar etiquetas y título
plt.xlabel('Año')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de valores OType por año')

# Mostrar el gráfico
plt.legend(title='OType', labels=['OType 1', 'OType 2', 'OType 3', 'OType 9'])
plt.show()
# Out:
# /tmp/ipykernel_24357/1807723220.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['date'] = pd.to_datetime(filtered_data['date'], format='%Y.%m.%d %H:%M:%S')
# /tmp/ipykernel_24357/1807723220.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.loc[:, 'year'] = filtered_data['date'].dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data['date'] = pd.to_datetime(data['date'], format='%Y.%m.%d %H:%M:%S')

# Filtrar el DataFrame para obtener los valores de OType 1, 2, 3 y 9 desde el año 2000 en adelante
#filtered_data = data[(data['OType'].isin([1, 2, 3, 9])) & (data['date'].dt.year >= 2000)]
#filtered_data = data[data['OType'].isin([1, 2, 3, 9])]
filtered_data = data[data['OType'].isin([1, 2, 3])]
# Crear una figura con un tamaño adecuado

# Ordenar los datos por año y OType
filtered_data = filtered_data.sort_values(by=['date', 'OType'])


plt.figure(figsize=(14, 8))

#
# Configurar el estilo de Seaborn
sns.set(style="whitegrid")

#Definir una paleta de colores personalizada
custom_palette = sns.color_palette("Set1")

# Crear un gráfico de barras utilizando Seaborn
#sns.countplot(data=filtered_data, x='date', hue='OType', palette="Set1")
#sns.countplot(data=filtered_data, x=filtered_data['date'].dt.year, hue='OType', palette="Set1")
# Crear un gráfico de barras utilizando Seaborn
sns.countplot(data=filtered_data, x=filtered_data['date'].dt.year, hue='OType', palette=custom_palette)
#ax = sns.countplot(data=filtered_data, x=filtered_data['date'].dt.year, hue='OType', palette=custom_palette)
#ax2 = ax.twinx()
#sns.lineplot(data=filtered_data, x=filtered_data['date'].dt.year, y=filtered_data['MagnM'], ax=ax2, color='r')

# Configurar etiquetas y título
plt.xlabel('Año')
plt.ylabel('Frecuencia')
#ax.set_ylabel('Frecuencia')
#ax2.set_ylabel('Magnitud (MagnM)')
plt.title('Frecuencia de valores de OType por año')

# Rotar etiquetas en el eje X para una mejor legibilidad
plt.xticks(rotation=90)

# Limitar el eje X para mostrar solo los años desde 2000
#plt.xlim(pd.to_datetime('2000-01-01'), pd.to_datetime('2023-12-31'))

# Mostrar el gráfico
plt.legend(title='OType', labels=['OType 1', 'OType 2', 'OType 3'])
plt.tight_layout()
plt.show()
# Out:
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data['date'] = pd.to_datetime(data['date'], format='%Y.%m.%d %H:%M:%S')

# Filtrar el DataFrame para obtener los valores de OType 1, 2, 3 desde el año 2000 en adelante
filtered_data = data[(data['OType'].isin([1, 2, 3])) & (data['date'].dt.year >= 2000)]

# Crear una figura con un tamaño adecuado
plt.figure(figsize=(14, 8))

# Configurar el estilo de Seaborn
sns.set(style="whitegrid")

# Definir una paleta de colores personalizada que representa la magnitud
color_palette = sns.color_palette("viridis", as_cmap=True)

# Crear un gráfico de barras utilizando Seaborn
sns.barplot(data=filtered_data, x=filtered_data['date'].dt.year, y=filtered_data['OType'], palette=color_palette)

# Configurar etiquetas y título
plt.xlabel('Año')
plt.ylabel('OType')
plt.title('Frecuencia de valores de OType por año (Color codificado por Magnitud)')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 20
#      17 color_palette = sns.color_palette("viridis", as_cmap=True)
#      19 # Crear un gráfico de barras utilizando Seaborn
# ---> 20 sns.barplot(data=filtered_data, x=filtered_data['date'].dt.year, y=filtered_data['OType'], palette=color_palette)
#      22 # Configurar etiquetas y título
#      23 plt.xlabel('Año')
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:1532, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1529 """Initialize the plotter."""
#    1530 self.establish_variables(x, y, hue, data, orient,
#    1531                          order, hue_order, units)
# -> 1532 self.establish_colors(color, palette, saturation)
#    1533 self.estimate_statistic(estimator, errorbar, n_boot, seed)
#    1535 self.dodge = dodge
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:696, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     693             levels = self.hue_names
#     694         palette = [palette[l] for l in levels]
# --> 696     colors = color_palette(palette, n_colors)
#     698 # Desaturate a bit because these are patches
#     699 if saturation < 1:
#
# File ~/.local/lib/python3.10/site-packages/seaborn/palettes.py:245, in color_palette(palette, n_colors, desat, as_cmap)
#     240     palette = [desaturate(c, desat) for c in palette]
#     242 if not as_cmap:
#     243
#     244     # Always return as many colors as we asked for
# --> 245     pal_cycle = cycle(palette)
#     246     palette = [next(pal_cycle) for _ in range(n_colors)]
#     248     # Always return in r, g, b tuple format
#
# TypeError: 'ListedColormap' object is not iterable

# %%
filtered_data = data[data['OType'] == 1]
filtered_data
# Out:
#                    date  MagnM  Axym  Azrange  TminM  DminM  OType  Bmax  \
# 54  2006.07.09 21:36:00    3.8  1.95     2.88     34  -0.38      1   9.7
# 60  2006.07.27 13:53:00    1.0  0.82     1.53     14  -0.25      1  14.0
# 63  2006.08.07 00:35:00    0.9  0.78     1.44     28  -0.38      1  18.1
# 66  2006.08.17 07:20:00    1.4  1.51     1.29      8  -0.31      1   8.7
# 74  2006.09.04 00:20:00    0.9  1.25     1.52      4  -0.28      1  14.2
# ..                  ...    ...   ...      ...    ...    ...    ...   ...
# 38  2019.05.10 17:54:00    1.6  0.99     0.75     26  -0.28      1  11.9
# 44  2019.05.26 22:14:00    1.1  0.94     1.08     14  -0.29      1  11.8
# 38  2020.04.20 02:33:00    0.9  0.96     0.74     10  -0.34      1  15.9
# 84  2020.10.19 14:41:00    0.6  0.62     0.93     12  -0.19      1   9.1
# 86  2020.10.23 13:20:00    1.2  0.82     0.63     52  -0.34      1  13.3
#
#     Bzmin   Vmax  Dstmin
# 54   -6.4  438.0   -23.0
# 60   -8.5  663.0   -47.0
# 63   -7.4  630.0   -44.0
# 66   -6.4  355.0   -17.0
# 74   -5.1  621.0   -41.0
# ..    ...    ...     ...
# 38  -10.5  382.0     NaN
# 44   -6.3  372.0   -16.0
# 38  -14.3  371.0   -59.0
# 84   -3.0  419.0   -13.0
# 86   -3.5  613.0   -38.0
#
# [185 rows x 11 columns]

# %%
filtered_data.loc[54]['date']
# Out:
# '2006.07.09 21:36:00'

# %%
# Importar la biblioteca datetime
from datetime import datetime

# Función para convertir la fecha
def convert_date_to_continuous_number(date_str):
    # Convertir la fecha en un objeto datetime
    date_obj = datetime.strptime(date_str, '%Y.%m.%d %H:%M:%S')
    
    # Construir un número continuo a partir de la fecha
    continuous_number = int(date_obj.strftime('%Y%m%d%H%M'))
    
    return continuous_number

# Aplicar la función a la columna 'date' en filtered_data
filtered_data['continuous_date'] = filtered_data['date'].apply(convert_date_to_continuous_number)

# Verificar los resultados
print(filtered_data)
# Out:
#                    date  MagnM  Axym  Azrange  TminM  DminM  OType  Bmax  \
# 54  2006.07.09 21:36:00    3.8  1.95     2.88     34  -0.38      1   9.7
# 60  2006.07.27 13:53:00    1.0  0.82     1.53     14  -0.25      1  14.0
# 63  2006.08.07 00:35:00    0.9  0.78     1.44     28  -0.38      1  18.1
# 66  2006.08.17 07:20:00    1.4  1.51     1.29      8  -0.31      1   8.7
# 74  2006.09.04 00:20:00    0.9  1.25     1.52      4  -0.28      1  14.2
# ..                  ...    ...   ...      ...    ...    ...    ...   ...
# 38  2019.05.10 17:54:00    1.6  0.99     0.75     26  -0.28      1  11.9
# 44  2019.05.26 22:14:00    1.1  0.94     1.08     14  -0.29      1  11.8
# 38  2020.04.20 02:33:00    0.9  0.96     0.74     10  -0.34      1  15.9
# 84  2020.10.19 14:41:00    0.6  0.62     0.93     12  -0.19      1   9.1
# 86  2020.10.23 13:20:00    1.2  0.82     0.63     52  -0.34      1  13.3
#
#     Bzmin   Vmax  Dstmin  continuous_date
# 54   -6.4  438.0   -23.0     200607092136
# 60   -8.5  663.0   -47.0     200607271353
# 63   -7.4  630.0   -44.0     200608070035
# 66   -6.4  355.0   -17.0     200608170720
# 74   -5.1  621.0   -41.0     200609040020
# ..    ...    ...     ...              ...
# 38  -10.5  382.0     NaN     201905101754
# 44   -6.3  372.0   -16.0     201905262214
# 38  -14.3  371.0   -59.0     202004200233
# 84   -3.0  419.0   -13.0     202010191441
# 86   -3.5  613.0   -38.0     202010231320
#
# [185 rows x 12 columns]
# /tmp/ipykernel_9641/409621421.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['continuous_date'] = filtered_data['date'].apply(convert_date_to_continuous_number)

# %%
filtered_data['continuous_date'].iloc[0]
# Out:
# 200607092136

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Asegúrate de que la columna 'date' sea un objeto datetime
data['date'] = pd.to_datetime(data['date'], format='%Y.%m.%d %H:%M:%S')



# Filtrar el DataFrame para obtener solo los valores de OType 1, 2, 3 y 9
filtered_data = data[data['OType'].isin([1, 2, 3, 9])]
filtered_data['year'] = filtered_data['date'].dt.year



# Crear un violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(data=filtered_data, x=(filtered_data['year']) , y='MagnM', hue='OType', inner="point", palette="Set1")
plt.xlabel('Año')
plt.ylabel('Magnitud (MagnM)')
plt.title('Distribución de Magnitud por Año y OType')
plt.show()
# Out:
# /tmp/ipykernel_24357/3449007342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['year'] = filtered_data['date'].dt.year
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jennifer/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import requests
import pandas as pd
from io import StringIO

# Tomar el primer enlace
first_url = f"http://spaceweather.izmiran.ru/dbs/fds/events/{filtered_data['continuous_date'].iloc[0]}.txt"

# Realizar una solicitud GET al primer enlace
response = requests.get(first_url)

if response.status_code == 200:
    # Leer el contenido del primer enlace como una lista de líneas
    lines = response.text.splitlines()
    
    # Tomar la primera columna del primer dataset y convertirla en el encabezado
    header = lines[0].split('\t')[0]
    
    # Crear un DataFrame vacío con el encabezado
    new_data = pd.DataFrame(columns=[header])
    
    # Iterar a través de las fechas en la columna 'date' de filtered_data
    for date in filtered_data['continuous_date']:
        # Construir la URL correspondiente
        url = f"http://spaceweather.izmiran.ru/dbs/fds/events/{date}.txt"
        
        # Realizar una solicitud GET a la URL
        response = requests.get(url)
        
        if response.status_code == 200:
            # Leer el contenido de la página como una lista de líneas
            lines = response.text.splitlines()
            
            # Tomar la segunda columna de cada dataset y añadirla como una nueva columna al DataFrame
            data = [line.split('\t')[1] for line in lines]
            
            # Agregar una nueva columna al DataFrame
            new_data[date] = data

# Restablecer el índice del nuevo DataFrame
new_data.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data
# /tmp/ipykernel_9641/432665941.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[date] = data

# %%
new_data
# Out:
#     Date       200607092136 200607271353 200608070035 200608170720  \
# 0          NaN   2006-07-09   2006-07-27   2006-08-07   2006-08-17
# 1          NaN     21:36:00     13:53:00      0:35:00      7:20:00
# 2          NaN            1            1            1            1
# 3          NaN   2006-07-06         None         None         None
# 4          NaN      8:13:00         None         None         None
# ..         ...          ...          ...          ...          ...
# 108        NaN         90.5         None         None         None
# 109        NaN           93            0            0           95
# 110        NaN         None            1            1         None
# 111        NaN            0            0            0            0
# 112        NaN           31           18            0           27
#
#     200609040020 200612080435 200612141414 200612161755 200612181014  ...  \
# 0     2006-09-04   2006-12-08   2006-12-14   2006-12-16   2006-12-18  ...
# 1        0:20:00      4:35:00     14:14:00     17:55:00     10:14:00  ...
# 2              1            1            1            1            1  ...
# 3           None   2006-12-06   2006-12-13   2006-12-14         None  ...
# 4           None     18:29:00      2:14:00     21:07:00         None  ...
# ..           ...          ...          ...          ...          ...  ...
# 108         None         None        222.3         None         None  ...
# 109            0           94           77           77            0  ...
# 110            1         None         None         None            1  ...
# 111            0            0           92            0            0  ...
# 112            0           28           23           20            0  ...
#
#     201804200021 201805051025 201805221218 201805311446 201809290053  \
# 0     2018-04-20   2018-05-05   2018-05-22   2018-05-31   2018-09-29
# 1        0:21:00     10:25:00     12:18:00     14:46:00      0:53:00
# 2              1            1            1            1            1
# 3           None         None         None         None         None
# 4           None         None         None         None         None
# ..           ...          ...          ...          ...          ...
# 108         None         None         None         None         None
# 109         None         None         None         None         None
# 110         None         None         None         None         None
# 111            0            0            0            0            0
# 112         None         None         None         None         None
#
#     201905101754 201905262214 202004200233 202010191441 202010231320
# 0     2019-05-10   2019-05-26   2020-04-20   2020-10-19   2020-10-23
# 1       17:54:00     22:14:00      2:33:00     14:41:00     13:20:00
# 2              1            1            1            1            1
# 3           None         None         None         None         None
# 4           None         None         None         None         None
# ..           ...          ...          ...          ...          ...
# 108         None         None         None         None         None
# 109         None           93         None         None         None
# 110         None         None         None         None         None
# 111            0            0            0            0            0
# 112         None         None         None         None         None
#
# [113 rows x 186 columns]

# %%
import requests
import pandas as pd
from io import StringIO

# Tomar el primer enlace
first_url = f"http://spaceweather.izmiran.ru/dbs/fds/events/{filtered_data['continuous_date'].iloc[0]}.txt"

# Realizar una solicitud GET al primer enlace
response = requests.get(first_url)

# %%
if response.status_code == 200:
    # Leer el contenido de la respuesta
    file_content = response.text

    # Puedes imprimir el contenido para verificar
    print(file_content)

    # Para convertir el contenido en un DataFrame
    data = pd.read_csv(StringIO(file_content), sep='\s+', engine='python')
    # Eliminar espacios en los valores de la primera columna
    data.iloc[:, 0] = data.iloc[:, 0].str.strip()

data
# Out:
# Date      	2006-07-09
# Time      	21:36:00
# Otype      	1
# Sdate      	2006-07-06
# Stime      	8:13:00
# Stype      	1.0
# Source      	SF+CH
# Qs      	4
# Vsp      	1043.0
# Vmean      	487.0
# VmeanC      	486
# Vmax      	438.0
# tVmax      	2
# Bmax      	9.7
# tBmax      	3
# VmBm      	2.12
# Bzmin      	-6.4
# ABzmax      	7.2
# BzmtoBm      	0.742
# KTmax      	1.919
# tKTmax      	3.0
# KTmin      	0.262
# tKTmin      	28.0
# Bemax      	25.82
# tBemax      	8.0
# Bemin      	0.38
# tBemin      	26.0
# Rbulk      	15.23
# B2Sum      	1.31
# Magn      	4.5
# MagnM      	3.8
# MagnL      	11.82
# MagnC      	4.5
# Tmin      	34
# TminM      	34
# Dmin      	-0.51
# tDmin      	22
# DminM      	-0.38
# tDminM      	4
# GrDmin      	55.69
# Dmax      	0.27
# tDmax      	25
# AftoB      	0.464
# GammaM      	0.84
# GammaD      	0.75
# tBef      	142.0
# tAft      	37.0
# tFrom      	37.0
# Kpmax      	3.33
# Apmax      	18.0
# Dstmin      	-23.0
# tDstmin      	18.0
# Fdata      	M 2.5/SX
# Xmagn      	2.5e-05
# Hlat      	-9.0
# Alat      	9.0
# Hlon      	34.0
# Sdur      	38
# Axym      	1.95
# Txymax      	26.0
# Axm      	0.03
# Aym      	1.95
# Azrange      	2.88
# Pxym      	89.1
# Axdm      	-0.45
# Aydm      	-0.27
# Azdm      	-0.33
# Axydm      	0.52
# Pxydm      	211.0
# D01      	-0.33
# D02      	-0.36
# AD02      	0.36
# AxytoAf      	0.31
# Axb      	0.61
# Ayb      	1.39
# Azb      	0.46
# Axyb      	1.52
# Pxyb      	60.8
# Ax0      	0.66
# Ay0      	1.0
# Az0      	0.04
# Axy0      	1.2
# Pxy0      	56.6
# Ax1      	0.61
# Ay1      	1.39
# Az1      	0.43
# Axy1      	1.52
# Pxy1      	66.3
# dx1b      	-0.15
# dy1b      	0.03
# dz1b      	-0.03
# dxy1b      	0.15
# dA11b      	0.16
# dz1b      	-0.03
# Adz1b      	0.03
# dPxy1b      	-102.4
# Pdxy1b      	168.7
# DP1b      	5.3
# CMEdate      	2006-07-06
# CMEtime      	8:54:04
# CMEwidth      	360
# CMEangle      	-999
# MCstartdate      	None
# MCstarttime      	None
# MCdur      	-1
# RMC      	None
# EruptA      	33.9
# EruptD      	56.6
# EruptAD      	90.5
# Ind      	93
# Spol      	None
# GLE      	0
# SSN      	31
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[36], line 9
#       6 print(file_content)
#       8 # Para convertir el contenido en un DataFrame
# ----> 9 data = pd.read_csv(StringIO(file_content), sep='\s+', engine='python')
#      10 # Eliminar espacios en los valores de la primera columna
#      11 data.iloc[:, 0] = data.iloc[:, 0].str.strip()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/python_parser.py:286, in PythonParser.read(self, rows)
#     283     indexnamerow = content[0]
#     284     content = content[1:]
# --> 286 alldata = self._rows_to_cols(content)
#     287 data, columns = self._exclude_implicit_index(alldata)
#     289 conv_data = self._convert_data(data)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/python_parser.py:1058, in PythonParser._rows_to_cols(self, content)
#    1052             reason = (
#    1053                 "Error could possibly be due to quotes being "
#    1054                 "ignored when a multi-char delimiter is used."
#    1055             )
#    1056             msg += ". " + reason
# -> 1058         self._alert_malformed(msg, row_num + 1)
#    1060 # see gh-13320
#    1061 zipped_content = list(lib.to_object_array(content, min_width=col_len).T)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/python_parser.py:779, in PythonParser._alert_malformed(self, msg, row_num)
#     762 """
#     763 Alert a user about a malformed row, depending on value of
#     764 `self.on_bad_lines` enum.
#    (...)
#     776     even though we 0-index internally.
#     777 """
#     778 if self.on_bad_lines == self.BadLineHandleMethod.ERROR:
# --> 779     raise ParserError(msg)
#     780 if self.on_bad_lines == self.BadLineHandleMethod.WARN:
#     781     base = f"Skipping line {row_num}: "
#
# ParserError: Expected 2 fields in line 53, saw 3. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.

# %%
# Seleccionar la primera columna y convertirla en una lista de strings
columna1_lista = data.iloc[:, 0].astype(str).tolist()
columna1_lista
# Out:
# ['Time      ',
#  'Otype      ',
#  'Sdate      ',
#  'Stime      ',
#  'Stype      ',
#  'Source      ',
#  'Qs      ',
#  'Vsp      ',
#  'Vmean      ',
#  'VmeanC      ',
#  'Vmax      ',
#  'tVmax      ',
#  'Bmax      ',
#  'tBmax      ',
#  'VmBm      ',
#  'Bzmin      ',
#  'ABzmax      ',
#  'BzmtoBm      ',
#  'KTmax      ',
#  'tKTmax      ',
#  'KTmin      ',
#  'tKTmin      ',
#  'Bemax      ',
#  'tBemax      ',
#  'Bemin      ',
#  'tBemin      ',
#  'Rbulk      ',
#  'B2Sum      ',
#  'Magn      ',
#  'MagnM      ',
#  'MagnL      ',
#  'MagnC      ',
#  'Tmin      ',
#  'TminM      ',
#  'Dmin      ',
#  'tDmin      ',
#  'DminM      ',
#  'tDminM      ',
#  'GrDmin      ',
#  'Dmax      ',
#  'tDmax      ',
#  'AftoB      ',
#  'GammaM      ',
#  'GammaD      ',
#  'tBef      ',
#  'tAft      ',
#  'tFrom      ',
#  'Kpmax      ',
#  'Apmax      ',
#  'Dstmin      ',
#  'tDstmin      ',
#  'Fdata      ',
#  'Xmagn      ',
#  'Hlat      ',
#  'Alat      ',
#  'Hlon      ',
#  'Sdur      ',
#  'Axym      ',
#  'Txymax      ',
#  'Axm      ',
#  'Aym      ',
#  'Azrange      ',
#  'Pxym      ',
#  'Axdm      ',
#  'Aydm      ',
#  'Azdm      ',
#  'Axydm      ',
#  'Pxydm      ',
#  'D01      ',
#  'D02      ',
#  'AD02      ',
#  'AxytoAf      ',
#  'Axb      ',
#  'Ayb      ',
#  'Azb      ',
#  'Axyb      ',
#  'Pxyb      ',
#  'Ax0      ',
#  'Ay0      ',
#  'Az0      ',
#  'Axy0      ',
#  'Pxy0      ',
#  'Ax1      ',
#  'Ay1      ',
#  'Az1      ',
#  'Axy1      ',
#  'Pxy1      ',
#  'dx1b      ',
#  'dy1b      ',
#  'dz1b      ',
#  'dxy1b      ',
#  'dA11b      ',
#  'dz1b      ',
#  'Adz1b      ',
#  'dPxy1b      ',
#  'Pdxy1b      ',
#  'DP1b      ',
#  'CMEdate      ',
#  'CMEtime      ',
#  'CMEwidth      ',
#  'CMEangle      ',
#  'MCstartdate      ',
#  'MCstarttime      ',
#  'MCdur      ',
#  'RMC      ',
#  'EruptA      ',
#  'EruptD      ',
#  'EruptAD      ',
#  'Ind      ',
#  'Spol      ',
#  'GLE      ',
#  'SSN      ']

# %%
if response.status_code == 200:
    # Leer el contenido del primer enlace como una lista de líneas
    lines = response.text.splitlines()
    
    # Tomar la primera columna del primer dataset y convertirla en el encabezado
    header = lines[0].split('\t')[0]
    
    # Crear un DataFrame vacío con el encabezado
    new_data = pd.DataFrame(columns=[header])
new_data
# Out:
# Empty DataFrame
# Columns: [Date      ]
# Index: []

# %%
import re

if response.status_code == 200:
    # Leer el contenido de la respuesta
    file_content = response.text

    # Para convertir el contenido en un DataFrame
    data = pd.read_csv(StringIO(file_content), sep='\s+', engine='python')

    # Utilizar una expresión regular para eliminar cualquier caracter no deseado en la primera columna
    data.iloc[:, 0] = data.iloc[:, 0].apply(lambda x: re.sub(r'\W', '', x))

# Seleccionar la primera columna y convertirla en una lista de strings
columna1_lista = data.iloc[:, 0].astype(str).tolist()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[38], line 8
#       5 file_content = response.text
#       7 # Para convertir el contenido en un DataFrame
# ----> 8 data = pd.read_csv(StringIO(file_content), sep='\s+', engine='python')
#      10 # Utilizar una expresión regular para eliminar cualquier caracter no deseado en la primera columna
#      11 data.iloc[:, 0] = data.iloc[:, 0].apply(lambda x: re.sub(r'\W', '', x))
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/python_parser.py:286, in PythonParser.read(self, rows)
#     283     indexnamerow = content[0]
#     284     content = content[1:]
# --> 286 alldata = self._rows_to_cols(content)
#     287 data, columns = self._exclude_implicit_index(alldata)
#     289 conv_data = self._convert_data(data)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/python_parser.py:1058, in PythonParser._rows_to_cols(self, content)
#    1052             reason = (
#    1053                 "Error could possibly be due to quotes being "
#    1054                 "ignored when a multi-char delimiter is used."
#    1055             )
#    1056             msg += ". " + reason
# -> 1058         self._alert_malformed(msg, row_num + 1)
#    1060 # see gh-13320
#    1061 zipped_content = list(lib.to_object_array(content, min_width=col_len).T)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/python_parser.py:779, in PythonParser._alert_malformed(self, msg, row_num)
#     762 """
#     763 Alert a user about a malformed row, depending on value of
#     764 `self.on_bad_lines` enum.
#    (...)
#     776     even though we 0-index internally.
#     777 """
#     778 if self.on_bad_lines == self.BadLineHandleMethod.ERROR:
# --> 779     raise ParserError(msg)
#     780 if self.on_bad_lines == self.BadLineHandleMethod.WARN:
#     781     base = f"Skipping line {row_num}: "
#
# ParserError: Expected 2 fields in line 53, saw 3. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
