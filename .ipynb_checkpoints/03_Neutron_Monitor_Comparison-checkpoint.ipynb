# %% [markdown]
# # Scaler dataframe for Auger Open Data
# ## A Neutron Monitor Comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import augerscalerpy.plot_config as pc
from augerscalerpy.scaler_cleaning import scaler_clean, plot_data ## ESTA SÍ ESSSSS LA FORMAAAAAAAAAAA!!!!!!!!

# %% [raw]
# NM = pd.read_csv('nm_data/NM_izmiran.csv')

# %% [markdown]
# ## Bases de datos disponibles
#
# #### https://www.nmdb.eu/nest/
# #### https://cidas.isee.nagoya-u.ac.jp/WDCCR/station_list.php
# #### Las páginas oficiales de las estaciones: http://cr0.izmiran.ru/common/
# #### El servicio de IZMIRAN http://cr0.izmiran.ru/rome/main.htm
#
# Fuentes de datos oficiales con los datos corregidos:
# #### México: http://www.cosmicrays.unam.mx/
# #### Oulu: https://cosmicrays.oulu.fi/
# #### Rome: Revisar este --> http://webusers.fis.uniroma3.it/svirco/pag_2.html

# %% [markdown]
# # DATOS DE NMDB: the Neutron Monitor Database
# ## Real-Time Database for high-resolution Neutron Monitor measurements
#
# Trabajo con datos de algunas estaciones directamente.

# %% [markdown]
# ### Importando datos del dataframe final creado

# %%
#combined_df = pd.read_csv('nm_data/CRI_auger_NM_6H_NORM.csv') ############## AUGER NORMALIZADO ZSCORE
combined_df = pd.read_csv('nm_data/CRI_auger_NM_6H_MIMMAX.csv') ############## DATOS NORMALIZADOS CON MINMAX
combined_df = pd.read_csv('nm_data/CRI_auger_NM_6H_RAW.csv') ############# DATOS SIN NORMALIZAR, LIMPIOS

# %%
# Filtrar los datos para el rango de años de enero de 2006 a septiembre de 2021
start_date = '2006-01-01'
end_date = '2021-09-30'
filtered_df = combined_df[(combined_df['date'] >= start_date) & (combined_df['date'] <= end_date)]

# %%
filtered_df
# Out:
#                             date    oulu        auger    mexico  athenas  \
# 23376  2006-01-01 00:00:00+00:00  6133.5  1607.777083  216.7285  54.7335
# 23377  2006-01-01 06:00:00+00:00  6141.5  1625.045417  218.4225  54.5820
# 23378  2006-01-01 12:00:00+00:00  6131.5  1634.113333  218.1540  54.3640
# 23379  2006-01-01 18:00:00+00:00  6139.0  1617.528333  217.8415  54.4610
# 23380  2006-01-02 00:00:00+00:00  6145.5  1616.656000  218.5235  54.6025
# ...                          ...     ...          ...       ...      ...
# 46375  2021-09-28 18:00:00+00:00  6611.0  1652.550000  227.9815  55.7330
# 46376  2021-09-29 00:00:00+00:00  6617.5  1650.236250  227.2000  55.8740
# 46377  2021-09-29 06:00:00+00:00  6649.0  1661.103056  228.2050  55.7885
# 46378  2021-09-29 12:00:00+00:00  6647.5  1669.282361  228.1630  55.7660
# 46379  2021-09-29 18:00:00+00:00  6646.5  1647.808611  227.5420  55.8835
#
#            roma    tsumeb    thule     sopo   newak
# 23376  149.1805  325.4490  118.018  298.170  93.997
# 23377  148.9705  325.1085  118.517  298.170  94.558
# 23378  148.4740  323.5560  118.423  298.170  94.582
# 23379  149.0880  324.6760  118.223  298.170  94.277
# 23380  149.3145  324.5460  118.388  298.170  94.565
# ...         ...       ...      ...      ...     ...
# 46375  126.7505  327.2220  127.562  320.348  98.633
# 46376  127.2710  327.2220  127.540  319.917  98.402
# 46377  127.3325  327.2220  128.003  320.857  98.847
# 46378  127.1360  327.2220  128.010  321.402  99.260
# 46379  127.1655  327.2220  128.103  320.595  99.192
#
# [23004 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Asegúrate de que 'date' sea de tipo datetime
filtered_df['date'] = pd.to_datetime(filtered_df['date'])

athenas = filtered_df['athenas']
oulu = filtered_df['oulu']
# roma = combined_df['counts/s_3']
mexico = filtered_df['mexico']
tsumeb = filtered_df['tsumeb']
auger = filtered_df['auger']

plt.figure(figsize=(12, 6))
# Scatter plots
# Gráficos de dispersión con fechas en el eje x
plt.scatter(filtered_df['date'], filtered_df['thule'], color='blue', label='Atenas, Grecia. R=8.53', marker='o', s=1)
plt.scatter(filtered_df['date'], filtered_df['mexico'], color='orange', label='México DC. R=9.53', marker='o', s=1)
plt.scatter(filtered_df['date'], filtered_df['sopo'], color='fuchsia', label='Tsumeb, Namibia. R=9.15', marker='o', s=1)
plt.scatter(filtered_df['date'], filtered_df['auger']-1500, color='black', label='P. Auger, Argentina. R=9.8', marker='o', s=1)
plt.scatter(filtered_df['date'], filtered_df['oulu']-6500, color='lime', label='Oulu, Finlandia. R=0.81', marker='o', s=1)

# Obtiene los ejes actuales
ax = plt.gca()

# Establece la escala del eje Y en logarítmica
#ax.set_yscale("log")

# Formateo para el eje x para mostrar solo los años o cualquier otro formato preferido
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_major_locator(mdates.YearLocator(3))



plt.xlabel('Año', fontsize=15)
plt.ylabel('CRI', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')

# Crear una leyenda personalizada con marcadores más grandes
legend = plt.legend(fontsize=12)
for handle in legend.legendHandles:
    handle.set_sizes([50])  # Ajustar el tamaño de los marcadores en la leyenda

#for line in legend.get_lines():
#    line.set_markersize(10)  # Ajustar el tamaño de los marcadores en la leyenda

plt.grid()
#plt.savefig('NM_Auger_MEXICO.pdf', dpi=300)
plt.savefig('NM_Auger_RAW.png')
plt.show()
# Out:
# /tmp/ipykernel_7080/1217290965.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['date'] = pd.to_datetime(filtered_df['date'])
# /tmp/ipykernel_7080/1217290965.py:43: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend.legendHandles:
