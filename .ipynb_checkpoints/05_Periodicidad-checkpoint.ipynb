# %% [markdown]
# ## Scaler dataframe for Auger Open Data
# ### Periodicity analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from augerscalerpy.scaler_clear import plotscaler

# %%
import astropy
from astropy.time import Time
from astropy.coordinates import EarthLocation, AltAz, get_body
import astropy.units as u

# %%
### PROMEDIO DE VENTANA MÓVIL 
### ____________________________UN DATO CADA MEDIA__________ TODOS LOS AÑOS (MEJORAR)

scaler3600s = plotscaler('scaler_ALL_hourly_11abril.csv','scaler_3600s')
# Out:
# Hay  (11805, 4) líneas vacías

# %%
scaler_sidereal = scaler3600s.copy()
scaler_sidereal
# Out:
#                       Date  ScalerCorr  pressure  activeSD
# 1364   2006-01-01 00:29:46     1603.57   858.762   544.333
# 1365   2006-01-01 00:59:46     1603.88   859.376   549.250
# 1366   2006-01-01 01:29:46     1604.98   859.990   554.083
# 1367   2006-01-01 01:59:46     1606.05   860.604   558.083
# 1368   2006-01-01 02:29:46     1607.02   861.121   561.833
# ...                    ...         ...       ...       ...
# 253138 2020-12-31 20:59:46     1656.40   858.720   424.167
# 253139 2020-12-31 21:29:46     1654.27   858.809   422.500
# 253140 2020-12-31 21:59:46     1654.61   858.950   421.833
# 253141 2020-12-31 22:29:46     1655.48   859.195   423.333
# 253142 2020-12-31 22:59:46     1654.73   859.466   425.083
#
# [225030 rows x 4 columns]

# %%
print(scaler_sidereal['Date'].dtype)
# Out:
# datetime64[ns]

# %%
scaler_sidereal = scaler_sidereal.dropna()
scaler_sidereal = scaler_sidereal.reset_index(drop=True)
print(scaler_sidereal)
# Out:
#                       Date  ScalerCorr  pressure  activeSD
# 0      2006-01-01 00:29:46     1603.57   858.762   544.333
# 1      2006-01-01 00:59:46     1603.88   859.376   549.250
# 2      2006-01-01 01:29:46     1604.98   859.990   554.083
# 3      2006-01-01 01:59:46     1606.05   860.604   558.083
# 4      2006-01-01 02:29:46     1607.02   861.121   561.833
# ...                    ...         ...       ...       ...
# 225024 2020-12-31 20:59:46     1656.40   858.720   424.167
# 225025 2020-12-31 21:29:46     1654.27   858.809   422.500
# 225026 2020-12-31 21:59:46     1654.61   858.950   421.833
# 225027 2020-12-31 22:29:46     1655.48   859.195   423.333
# 225028 2020-12-31 22:59:46     1654.73   859.466   425.083
#
# [225029 rows x 4 columns]

# %%
print(scaler_sidereal.columns)
# Out:
# Index(['Date', 'ScalerCorr', 'pressure', 'activeSD'], dtype='object')

# %%
print(scaler_sidereal.head())
# Out:
#                  Date  ScalerCorr  pressure  activeSD
# 0 2006-01-01 00:29:46     1603.57   858.762   544.333
# 1 2006-01-01 00:59:46     1603.88   859.376   549.250
# 2 2006-01-01 01:29:46     1604.98   859.990   554.083
# 3 2006-01-01 01:59:46     1606.05   860.604   558.083
# 4 2006-01-01 02:29:46     1607.02   861.121   561.833

# %%
# Definir la ubicación geográfica
malargue_location = EarthLocation(lat=-35.4889*u.deg, lon=-69.5857*u.deg)

# %%
# Convertir la columna "Date" a formato Time
scaler_sidereal['Date'] = Time(scaler_sidereal['Date'])
times = Time(scaler_sidereal['Date'])

# %%
# Convertir las unidades de tiempo a UTC
times = times.utc

# %%
# Obtener el tiempo sidéreo
sidereal_times = times.sidereal_time('mean', longitude=malargue_location.lon)

# %%
# Agregar la columna 'Sidereal_Time' al dataframe
scaler_sidereal['Sidereal_Time'] = sidereal_times

# %% [raw]
# # from astropy.time import Time
# from astropy.coordinates import EarthLocation
# import pandas as pd
#
# # Verificar el tipo de datos en la columna 'Date'
# print(scaler_sidereal['Date'].dtype)
#
# # Verificar y eliminar valores nulos
# scaler_sidereal = scaler_sidereal.dropna(subset=['Date'])
#
# # Convertir la columna 'Date' a formato datetime
# scaler_sidereal['Date'] = pd.to_datetime(scaler_sidereal['Date'])
#
# # Verificar si hay valores no numéricos o inconsistentes
# # y realizar las manipulaciones necesarias
#
# # Convertir la columna 'Date' a objetos Time y asegurarse de que estén en UTC
# times = Time(scaler_sidereal['Date']).utc
#
# # Calcular el tiempo sidéreo
# malargue_location = EarthLocation(lat=-35.4889, lon=-69.5857)
# sidereal_times = times.sidereal_time('mean', longitude=malargue_location.lon)
#
# # Agregar la columna 'Sidereal_Time' al dataframe
# scaler_sidereal['Sidereal_Time'] = sidereal_times
#
# # Imprimir el dataframe con la columna 'Sidereal_Time'
# print(scaler_sidereal)

# %%
import matplotlib.pyplot as plt

# Graficar la columna "ScalerCorr" en función de "Sidereal Time"
plt.figure(figsize=(15, 6))  # Ancho: 10 pulgadas, Alto: 6 pulgadas
x_ticks = np.arange(0, 26, 1)
plt.xticks(x_ticks)
# Habilitar la cuadrícula
plt.grid(True)
plt.scatter(scaler_sidereal["Sidereal_Time"], scaler_sidereal["ScalerCorr"])
plt.xlabel("Sidereal Time")
plt.ylabel("ScalerCorr")
plt.title("ScalerCorr vs Sidereal Time")
plt.show()

# %%
from astropy.time import Time

# Convertir la columna 'Sidereal_Time' a objetos Time
sidereal_times = Time(scaler_sidereal['Sidereal_Time'])

# Convertir las fechas de filtrado a objetos Time
start_date = Time("2017-08-01")
end_date = Time("2017-09-01")

# Filtrar los datos para el mes de agosto de 2017
mes = scaler_sidereal[(sidereal_times >= start_date) & (sidereal_times < end_date)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7f3cb8bbf460> in <module>
#       2
#       3 # Convertir la columna 'Sidereal_Time' a objetos Time
# ----> 4 sidereal_times = Time(scaler_sidereal['Sidereal_Time'])
#       5
#       6 # Convertir las fechas de filtrado a objetos Time
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in __init__(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, location, copy)
#    1525                 self._set_scale(scale)
#    1526         else:
# -> 1527             self._init_from_vals(val, val2, format, scale, copy,
#    1528                                  precision, in_subfmt, out_subfmt)
#    1529             self.SCALES = TIME_TYPES[self.scale]
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in _init_from_vals(self, val, val2, format, scale, copy, precision, in_subfmt, out_subfmt)
#     379
#     380         # Parse / convert input values into internal jd1, jd2 based on format
# --> 381         self._time = self._get_time_fmt(val, val2, format, scale,
#     382                                         precision, in_subfmt, out_subfmt)
#     383         self._format = self._time.name
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in _get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt)
#     424                   and format.lower() in self.FORMATS):
#     425             if format is None:
# --> 426                 raise ValueError("No time format was given, and the input is "
#     427                                  "not unique")
#     428             else:
#
# ValueError: No time format was given, and the input is not unique

# %%
import matplotlib.pyplot as plt



# Graficar la columna "ScalerCorr" en función de "Sidereal Time" para el mes de agosto de 2017
plt.figure(figsize=(15, 6))
x_ticks = np.arange(0, 26, 1)
plt.xticks(x_ticks)
plt.grid(True)
plt.scatter(mes["Sidereal_Time"], mes["ScalerCorr"])
plt.xlabel("Sidereal Time")
plt.ylabel("ScalerCorr")
plt.title("ScalerCorr vs Sidereal Time (August 2017)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-99b0d28a88d6> in <module>
#       2
#       3 # Filtrar los datos para el mes de agosto de 2017
# ----> 4 mes = scaler_sidereal[(scaler_sidereal['Date'] >= "2017-08-01") & (scaler_sidereal['Date'] < "2017-09-01")]
#       5
#       6 # Graficar la columna "ScalerCorr" en función de "Sidereal Time" para el mes de agosto de 2017
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5499
#    5500         with np.errstate(all="ignore"):
# -> 5501             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5502
#    5503         return self._construct_result(res_values, name=res_name)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in __lt__(self, other)
#    1403
#    1404     def __lt__(self, other):
# -> 1405         return self._time_comparison(other, operator.lt)
#    1406
#    1407     def __le__(self, other):
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in _time_comparison(self, other, op)
#    1384         if other.__class__ is not self.__class__:
#    1385             try:
# -> 1386                 other = self.__class__(other, scale=self.scale)
#    1387             except Exception:
#    1388                 # Let other have a go.
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in __init__(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, location, copy)
#    1525                 self._set_scale(scale)
#    1526         else:
# -> 1527             self._init_from_vals(val, val2, format, scale, copy,
#    1528                                  precision, in_subfmt, out_subfmt)
#    1529             self.SCALES = TIME_TYPES[self.scale]
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in _init_from_vals(self, val, val2, format, scale, copy, precision, in_subfmt, out_subfmt)
#     379
#     380         # Parse / convert input values into internal jd1, jd2 based on format
# --> 381         self._time = self._get_time_fmt(val, val2, format, scale,
#     382                                         precision, in_subfmt, out_subfmt)
#     383         self._format = self._time.name
#
# ~/.local/lib/python3.8/site-packages/astropy/time/core.py in _get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt)
#     437         for name, cls in formats:
#     438             try:
# --> 439                 return cls(val, val2, scale, precision, in_subfmt, out_subfmt)
#     440             except UnitConversionError:
#     441                 raise
#
# ~/.local/lib/python3.8/site-packages/astropy/time/formats.py in __init__(self, val1, val2, scale, precision, in_subfmt, out_subfmt, from_jd)
#     148         else:
#     149             val1, val2 = self._check_val_type(val1, val2)
# --> 150             self.set_jds(val1, val2)
#     151
#     152     @classmethod
#
# ~/.local/lib/python3.8/site-packages/astropy/time/formats.py in set_jds(self, val1, val2)
#    1358         else:
#    1359             try:
# -> 1360                 jd1, jd2 = self.get_jds_fast(val1, val2)
#    1361             except Exception:
#    1362                 # Fall through to the Python parser unless fast is forced.
#
# ~/.local/lib/python3.8/site-packages/astropy/time/formats.py in get_jds_fast(self, val1, val2)
#    1430         if status == 0:
#    1431             # All went well, finish the job
# -> 1432             jd1, jd2 = erfa.dtf2d(self.scale.upper().encode('ascii'),
#    1433                                   time_struct['year'],
#    1434                                   time_struct['month'],
#
# ~/.local/lib/python3.8/site-packages/erfa/core.py in dtf2d(scale, iy, im, id, ihr, imn, sec)
#   16676
#   16677     """
# > 16678     d1, d2, c_retval = ufunc.dtf2d(scale, iy, im, id, ihr, imn, sec)
#   16679     check_errwarn(c_retval, 'dtf2d')
#   16680     return d1, d2
#
# KeyboardInterrupt:

# %%
# Convertir la columna "Date" a objetos Time de astropy
scaler_sidereal['Date'] = Time(scaler_sidereal['Date'])

# Definir la fecha de inicio y fin para el filtrado
start_date = Time('2017-08-01')
end_date = Time('2017-08-31')

# Filtrar los datos para el mes de agosto de 2017
august_2017_data = scaler_sidereal[(scaler_sidereal['Date'] >= start_date) & (scaler_sidereal['Date'] <= end_date)]


# Graficar la columna "ScalerCorr" en función de "Sidereal Time" para agosto de 2017
plt.figure(figsize=(15, 6))
x_ticks = np.arange(0, 26, 1)
plt.xticks(x_ticks)
plt.grid(True)
plt.scatter(august_2017_data["Sidereal_Time"], august_2017_data["ScalerCorr"])
plt.xlabel("Sidereal Time")
plt.ylabel("ScalerCorr")
plt.title("ScalerCorr vs Sidereal Time (August 2017)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in _to_own_unit(self, value, check_precision)
#    1355         try:
# -> 1356             _value = value.to_value(self.unit)
#    1357         except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_value'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in to_value(self, unit, equivalencies)
#     746             try:
# --> 747                 scale = self.unit._to(unit)
#     748             except Exception:
#
# ~/.local/lib/python3.8/site-packages/astropy/units/core.py in _to(self, other)
#    1088
# -> 1089         raise UnitConversionError(
#    1090             f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit(dimensionless)' is not a scaled version of 'Unit("hourangle")'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# <ipython-input-62-f67d9efe4ea0> in <module>
#       7
#       8 # Filtrar los datos para el mes de agosto de 2017
# ----> 9 august_2017_data = scaler_sidereal[(scaler_sidereal['Date'] >= start_date) & (scaler_sidereal['Date'] <= end_date)]
#      10
#      11
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3444         # Do we have a (boolean) 1d indexer?
#    3445         if com.is_bool_indexer(key):
# -> 3446             return self._getitem_bool_array(key)
#    3447
#    3448         # We are left with two options: a single key, and a collection of keys,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3499         key = check_bool_indexer(self.index, key)
#    3500         indexer = key.nonzero()[0]
# -> 3501         return self._take_with_is_copy(indexer, axis=0)
#    3502
#    3503     def _getitem_multilevel(self, key):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3623         See the docstring of `take` for full explanation of the parameters.
#    3624         """
# -> 3625         result = self.take(indices=indices, axis=axis)
#    3626         # Maybe set copy if we didn't actually change the index.
#    3627         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3608         nv.validate_take((), kwargs)
#    3609
# -> 3610         self._consolidate_inplace()
#    3611
#    3612         new_data = self._mgr.take(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5554             self._mgr = self._mgr.consolidate()
#    5555
# -> 5556         self._protect_consolidate(f)
#    5557
#    5558     @final
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5542             return f()
#    5543         blocks_before = len(self._mgr.blocks)
# -> 5544         result = f()
#    5545         if len(self._mgr.blocks) != blocks_before:
#    5546             self._clear_item_cache()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in f()
#    5552
#    5553         def f():
# -> 5554             self._mgr = self._mgr.consolidate()
#    5555
#    5556         self._protect_consolidate(f)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     613         bm = type(self)(self.blocks, self.axes, verify_integrity=False)
#     614         bm._is_consolidated = False
# --> 615         bm._consolidate_inplace()
#     616         return bm
#     617
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     618     def _consolidate_inplace(self) -> None:
#     619         if not self.is_consolidated():
# --> 620             self.blocks = tuple(_consolidate(self.blocks))
#     621             self._is_consolidated = True
#     622             self._known_consolidated = True
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1968     new_blocks: list[Block] = []
#    1969     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1970         merged_blocks = _merge_blocks(
#    1971             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1972         )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1995             # Sequence[Union[int, float, complex, str, bytes, generic]],
#    1996             # Sequence[Sequence[Any]], SupportsArray]]
# -> 1997             new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    1998         else:
#    1999             bvals = [blk.values for blk in blocks]
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in __array_function__(self, function, types, args, kwargs)
#    1518         # implementation.
#    1519         if function in SUBCLASS_SAFE_FUNCTIONS:
# -> 1520             return super().__array_function__(function, types, args, kwargs)
#    1521
#    1522         elif function in FUNCTION_HELPERS:
#
# ~/.local/lib/python3.8/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in __array_function__(self, function, types, args, kwargs)
#    1523             function_helper = FUNCTION_HELPERS[function]
#    1524             try:
# -> 1525                 args, kwargs, unit, out = function_helper(*args, **kwargs)
#    1526             except NotImplementedError:
#    1527                 return self._not_implemented_or_raise(function, types)
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity_helper/function_helpers.py in concatenate(arrays, axis, out)
#     370     # TODO: make this smarter by creating an appropriately shaped
#     371     # empty output array and just filling it.
# --> 372     arrays, kwargs, unit, out = _iterable_helper(*arrays, out=out, axis=axis)
#     373     return (arrays,), kwargs, unit, out
#     374
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity_helper/function_helpers.py in _iterable_helper(out, *args, **kwargs)
#     362             raise NotImplementedError
#     363
# --> 364     arrays, unit = _quantities2arrays(*args)
#     365     return arrays, kwargs, unit, out
#     366
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity_helper/function_helpers.py in _quantities2arrays(unit_from_first, *args)
#     343     # as we want to allow arbitrary unit for 0, inf, and nan.
#     344     try:
# --> 345         arrays = tuple((q._to_own_unit(arg)) for arg in args)
#     346     except TypeError:
#     347         raise NotImplementedError
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity_helper/function_helpers.py in <genexpr>(.0)
#     343     # as we want to allow arbitrary unit for 0, inf, and nan.
#     344     try:
# --> 345         arrays = tuple((q._to_own_unit(arg)) for arg in args)
#     346     except TypeError:
#     347         raise NotImplementedError
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in _to_own_unit(self, value, check_precision)
#    1370             try:
#    1371                 as_quantity = Quantity(value)
# -> 1372                 _value = as_quantity.to_value(self.unit)
#    1373             except UnitsError:
#    1374                 # last chance: if this was not something with a unit
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in to_value(self, unit, equivalencies)
#     748             except Exception:
#     749                 # Short-cut failed; try default (maybe equivalencies help).
# --> 750                 value = self._to_value(unit, equivalencies)
#     751             else:
#     752                 value = self.view(np.ndarray)
#
# ~/.local/lib/python3.8/site-packages/astropy/units/quantity.py in _to_value(self, unit, equivalencies)
#     667         if equivalencies == []:
#     668             equivalencies = self._equivalencies
# --> 669         return self.unit.to(unit, self.view(np.ndarray),
#     670                             equivalencies=equivalencies)
#     671
#
# ~/.local/lib/python3.8/site-packages/astropy/units/core.py in to(self, other, value, equivalencies)
#    1124             return UNITY
#    1125         else:
# -> 1126             return self._get_converter(Unit(other),
#    1127                                        equivalencies=equivalencies)(value)
#    1128
#
# ~/.local/lib/python3.8/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#    1055                             pass
#    1056
# -> 1057             raise exc
#    1058
#    1059     def _to(self, other):
#
# ~/.local/lib/python3.8/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#    1040         # if that doesn't work, maybe we can do it with equivalencies?
#    1041         try:
# -> 1042             return self._apply_equivalencies(
#    1043                 self, other, self._normalize_equivalencies(equivalencies))
#    1044         except UnitsError as exc:
#
# ~/.local/lib/python3.8/site-packages/astropy/units/core.py in _apply_equivalencies(self, unit, other, equivalencies)
#    1016         other_str = get_err_str(other)
#    1017
# -> 1018         raise UnitConversionError(
#    1019             f"{unit_str} and {other_str} are not convertible")
#    1020
#
# UnitConversionError: '' (dimensionless) and 'hourangle' (angle) are not convertible

# %%
import matplotlib.pyplot as plt
# Suavizar los datos promediando los valores dentro de intervalos de tiempo más grandes
interval = 1  # Intervalo de tiempo en horas para el suavizado
smoothed_data = scaler_sidereal.groupby(pd.cut(scaler_sidereal["Sidereal_Time"], bins=np.arange(0, 25, interval))).mean()

# Verificar el tamaño de la muestra no excede el tamaño del DataFrame
sample_size = min(100, len(smoothed_data))

# Graficar una muestra de los datos suavizados como puntos
sampled_data = smoothed_data.sample(n=sample_size, replace=False)

# Ajustar el tamaño de la gráfica
plt.figure(figsize=(15, 6))  # Ancho: 10 pulgadas, Alto: 6 pulgadas
x_ticks = np.arange(0, 26, 1)
plt.xticks(x_ticks)
# Habilitar la cuadrícula
plt.grid(True)
# Graficar los puntos suavizados
plt.plot(sampled_data["Sidereal_Time"], sampled_data["ScalerCorr"], marker='o', linestyle='')

plt.xlabel("Sidereal Time")
plt.ylabel("ScalerCorr")
plt.title("ScalerCorr vs Sidereal Time")
# Ajustar los límites del eje x para mostrar cada hora hasta 25
plt.xlim(0, 25)

plt.show()

# %%
import matplotlib.pyplot as plt

# Suavizar los datos promediando los valores dentro de intervalos de tiempo más grandes
interval = 1  # Intervalo de tiempo en horas para el suavizado
smoothed_data = scaler_sidereal.groupby(pd.cut(scaler_sidereal["Sidereal_Time"], bins=np.arange(0, 25, interval))).mean()

# Verificar el tamaño de la muestra no excede el tamaño del DataFrame
sample_size = min(100, len(smoothed_data))

# Graficar una muestra de los datos suavizados como puntos
sampled_data = smoothed_data.sample(n=sample_size, replace=False)

# Obtener el promedio y desviación estándar para cada punto
means = sampled_data["ScalerCorr"]
stds = scaler_sidereal.groupby(pd.cut(scaler_sidereal["Sidereal_Time"], bins=np.arange(0, 25, interval))).std()["ScalerCorr"]

# Ajustar el tamaño de la gráfica
plt.figure(figsize=(15, 6))
x_ticks = np.arange(0, 26, 1)
plt.xticks(x_ticks)
# Habilitar la cuadrícula
plt.grid(True)

# Graficar los puntos suavizados con barras de error
plt.errorbar(sampled_data["Sidereal_Time"], means, yerr=stds, fmt='o', markersize=4, capsize=3,ecolor="LightCoral")

plt.xlabel("Sidereal Time")
plt.ylabel("ScalerCorr")
plt.title('All Scaler Data')

# Ajustar los límites del eje x para mostrar cada hora hasta 25
plt.xlim(0, 25)
plt.savefig("scaler_sidereal.png")
plt.show()

# %% [markdown]
# # Observando la periodicidad diaria en tiempo solar

# %%
#OBSERVANDO PERIODICIDAD DIARIA POR SIMPLE INSPECCIÓN

mes = scaler3600s[scaler3600s['Date'] >= "2017-06-01"]
#mes = scaler3600s[scaler3600s['Date'] >= pd.to_datetime("2015-06-01", utc=True)]

#mesjun = mes[mes['Date'] <= pd.to_datetime("2015-06-30", utc=True) ]
mesjun = mes[mes['Date'] <= "2017-06-30" ]

mesjun.plot(kind='scatter', s= 2, x='Date',y='ScalerCorr',rot=45,figsize=(10, 5),color='black')
plt.savefig('junio_2017.jpg')

plt.show()

# %%
mesjun['Day'] = mesjun['Date'].dt.day
# Out:
# <ipython-input-52-62998892503d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mesjun['Day'] = mesjun['Date'].dt.day

# %%
mesjun['Day']
# Out:
# 192302     1
# 192303     1
# 192304     1
# 192305     1
# 192306     1
#           ..
# 193449    29
# 193450    29
# 193451    29
# 193452    29
# 193453    29
# Name: Day, Length: 1157, dtype: int64

# %%
import matplotlib.pyplot as plt

# Seleccionamos los datos correspondientes al mes de agosto del 2017
mes = scaler3600s[(scaler3600s['Date'] >= "2017-08-01") & (scaler3600s['Date'] < "2017-09-01")]

#mes = scaler3600s[(scaler3600s['Date'] >= "2006-06-01") & (scaler3600s['Date'] < "2020-07-01")]

# Creamos una figura y un objeto de tipo Axes
fig, ax = plt.subplots(figsize=(15, 6))

# Graficamos los datos para cada día del mes
for day in sorted(set(mes['Date'].dt.day)):
    # Seleccionamos los datos correspondientes a ese día
    data = mes[mes['Date'].dt.day == day]
    # Graficamos los valores de la columna "ScalerCorr"
    #ax.plot(data['Date'].dt.hour, data['ScalerCorr'], label=f"Day {day}")
    ax.scatter(data['Date'].dt.hour, data['ScalerCorr'], label=f"Day {day}", s=1)

# Configuramos el eje horizontal para que muestre las horas en UTC del día de 0h a 24h
# Ajustar el tamaño de la gráfica
#ax.figsize=(15, 6)
ax.set_xlim(0, 23)
ax.set_xticks(range(0, 24, 2))
ax.set_xlabel("UTC Hour")

# Configuramos el eje vertical
ax.set_ylabel("ScalerCorr")

# Añadimos una leyenda
#ax.legend()
ax.set_title('Superposition of all days for Auger scalers (August 2017)')


# Mostramos la gráfica
plt.savefig('Scalers_August_2017_SUP.jpg')
ax.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Seleccionamos los datos correspondientes al mes de junio de 2016
#mes = scaler3600s[(scaler3600s['Date'] >= "2017-06-01") & (scaler3600s['Date'] < "2017-07-01")]
mes = scaler3600s[(scaler3600s['Date'] >= "2006-06-01") & (scaler3600s['Date'] < "2020-07-01")]

# Creamos una figura y un objeto de tipo Axes
fig, ax = plt.subplots(figsize=(15, 6))
ax.grid(True)
# Obtener el promedio y la desviación estándar para cada hora del día
promedios = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].mean()
desviaciones = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].std()

# Graficamos los datos para cada día del mes
#for day in sorted(set(mes['Date'].dt.day)):
    # Seleccionamos los datos correspondientes a ese día
#    data = mes[mes['Date'].dt.day == day]
    # Graficamos los valores de la columna "ScalerCorr"
    #ax.plot(data['Date'].dt.hour, data['ScalerCorr'], label=f"Day {day}")
#    ax.scatter(data['Date'].dt.hour, data['ScalerCorr'], label=f"Day {day}", s=1)

# Agregar la gráfica del promedio diario con su barra de error
ax.errorbar(promedios.index, promedios, yerr=desviaciones/10, fmt='x', label="Average",ecolor="LightCoral")

# Configuramos el eje horizontal para que muestre las horas en UTC del día de 0h a 24h
ax.set_xlim(0, 23)
ax.set_xticks(range(0, 24, 1))
ax.set_xlabel("UTC Hour")

# Configuramos el eje vertical
ax.set_ylabel("ScalerCorr")

# Añadimos una leyenda
#ax.legend()
ax.set_title('All Scaler Data')

# Mostramos la gráfica
plt.savefig('Scalers_All_SUP.png')

plt.show()

# %% [raw]
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Filtro de datos para un mes específico
# mes = scaler3600s[(scaler3600s['Date'] >= '2016-06-01') & (scaler3600s['Date'] < '2016-07-01')]
#
# # Obtener el promedio y la desviación estándar para cada hora del día
# promedios = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].mean()
# desviaciones = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].std()
#
# # Agrupación de datos por hora y obtener promedio de ScalerCorr para cada hora
# #promedio_dia = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].mean()
#
# # Agregar la gráfica del promedio diario con su barra de error
# ax.errorbar(promedios.index, promedios, yerr=desviaciones, fmt='x', label="Average")
#
# # Creamos una figura y un objeto de tipo Axes
# fig, ax = plt.subplots(figsize=(10, 6))
#
#
# # Graficar los datos
# #plt.plot(promedios.index, promedios.values)
# #plt.xlabel('Hora (UTC)')
# #plt.ylabel('ScalerCorr')
# #plt.title('Promedio diario de ScalerCorr para junio de 2016')
# #plt.show()
#
#
# # Configuramos el eje horizontal para que muestre las horas en UTC del día de 0h a 24h
# ax.set_xlim(0, 23)
# #ax.set_xticks(range(0, 24, 2))
# ax.set_xlabel("UTC Hour")
#
# # Configuramos el eje vertical
# ax.set_ylabel("ScalerCorr")
#
# # Añadimos una leyenda
# #ax.legend()
# ax.set_title('Superposition of all Scaler Data')
#
# # Mostramos la gráfica
# #plt.savefig('Scalers_AllPRU.png')
# ax.grid(True)
# plt.show()

# %%
import matplotlib.pyplot as plt

# Seleccionamos los datos correspondientes al mes de junio de 2016
mes = scaler3600s[(scaler3600s['Date'] >= "2017-08-01") & (scaler3600s['Date'] < "2017-09-01")]
#mes = scaler3600s[(scaler3600s['Date'] >= "2006-06-01") & (scaler3600s['Date'] < "2020-07-01")]

# Creamos una figura y un objeto de tipo Axes
fig, ax = plt.subplots(figsize=(10, 6))

# Obtener el promedio y la desviación estándar para cada hora del día
promedios = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].mean()
desviaciones = mes.groupby(mes['Date'].dt.hour)['ScalerCorr'].std()

# Graficamos los datos para cada día del mes
#for day in sorted(set(mes['Date'].dt.day)):
    # Seleccionamos los datos correspondientes a ese día
#    data = mes[mes['Date'].dt.day == day]
    # Graficamos los valores de la columna "ScalerCorr"
    #ax.plot(data['Date'].dt.hour, data['ScalerCorr'], label=f"Day {day}")
#    ax.scatter(data['Date'].dt.hour, data['ScalerCorr'], label=f"Day {day}", s=1)

# Agregar la gráfica del promedio diario con su barra de error
ax.errorbar(promedios.index, promedios, yerr=desviaciones, fmt='x', label="Average")

# Configuramos el eje horizontal para que muestre las horas en UTC del día de 0h a 24h
ax.set_xlim(0, 23)
ax.set_xticks(range(0, 24, 2))
ax.set_xlabel("UTC Hour")

# Configuramos el eje vertical
ax.set_ylabel("ScalerCorr")

# Añadimos una leyenda
#ax.legend()
ax.set_title('Average of Scaler Data (August 2017)')

# Mostramos la gráfica
plt.savefig('Scalers_All_SUP.png')
ax.grid(True)
plt.show()

# %%
################# USANDO LOS DATOS EN GPS
## OJO LOS VALORES TEMPORALES NO HAN SIDO CONVERTIDOS

# %%
df = pd.read_csv('scaler_ALL_hourly_11abril.csv')
scalerC = df.sort_values(by=['Date'])
nocero = scalerC[scalerC['ScalerCorr'] != 0 ]
taste = nocero
    #Cuántos valores cero hay? --No relevante
EMPTY =scalerC[scalerC['ScalerCorr'] == 0 ]
print("Hay ", EMPTY.shape, "líneas vacías")

    #AJUSTE EXCESOS
    #SDBAD1 =taste[taste['ScalerCorr'] > 1900 ]
    #SDBAD2 =taste[taste['ScalerCorr'] < 1500 ]
SDOK = taste[taste['ScalerCorr'] > 1580  ]
SDOK = SDOK[SDOK['ScalerCorr'] < 1700 ]
# Out:
# Hay  (11805, 4) líneas vacías

# %%
SDOK.plot(kind='scatter', s= 2,x='Date',y='ScalerCorr',color='black', figsize =(20,10))
plt.show()

# %%
# Convertir la columna "Date" a formato Time en UTC
times_utc = Time(SDOK["Date"], format='gps', scale='utc')

# %%
times_utc
# Out:
# <Time object: scale='utc' format='gps' value=[8.2011060e+08 8.2011240e+08 8.2011420e+08 ... 1.2934872e+09 1.2934890e+09
#  1.2934908e+09]>

# %%
# Definir la ubicación geográfica de Malargue, Argentina
malargue_location = EarthLocation(lat=-35.4889, lon=-69.5857)

# %%
# Convertir las unidades de tiempo a tiempo sidéreo
times_sidereal = times_utc.sidereal_time('mean', longitude=malargue_location.lon)

# %%
len(times_sidereal)
# Out:
# 225030

# %%
# Actualizar la columna "Date" del DataFrame con el tiempo sidéreo convertido
#SDOK["Date"] = times_sidereal
SDOK['Date'] = times_sidereal
# Imprimir el DataFrame con los datos convertidos a tiempo sidéreo
#print(SDOK)

# %%
SDOK
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:995, in DataFrame.__repr__(self)
#     993 else:
#     994     width = None
# --> 995 self.to_string(
#     996     buf=buf,
#     997     max_rows=max_rows,
#     998     min_rows=min_rows,
#     999     max_cols=max_cols,
#    1000     line_width=width,
#    1001     max_colwidth=max_colwidth,
#    1002     show_dimensions=show_dimensions,
#    1003 )
#    1005 return buf.getvalue()
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:1131, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#    1112 with option_context("display.max_colwidth", max_colwidth):
#    1113     formatter = fmt.DataFrameFormatter(
#    1114         self,
#    1115         columns=columns,
#    (...)
#    1129         decimal=decimal,
#    1130     )
# -> 1131     return fmt.DataFrameRenderer(formatter).to_string(
#    1132         buf=buf,
#    1133         encoding=encoding,
#    1134         line_width=line_width,
#    1135     )
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1053, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1050 from pandas.io.formats.string import StringFormatter
#    1052 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1053 string = string_formatter.to_string()
#    1054 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/string.py:25, in StringFormatter.to_string(self)
#      24 def to_string(self) -> str:
# ---> 25     text = self._get_string_representation()
#      26     if self.fmt.should_show_dimensions:
#      27         text = "".join([text, self.fmt.dimensions_info])
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/string.py:40, in StringFormatter._get_string_representation(self)
#      37 if self.fmt.frame.empty:
#      38     return self._empty_info_line
# ---> 40 strcols = self._get_strcols()
#      42 if self.line_width is None:
#      43     # no need to wrap around just print the whole frame
#      44     return self.adj.adjoin(1, *strcols)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/string.py:31, in StringFormatter._get_strcols(self)
#      30 def _get_strcols(self) -> list[list[str]]:
# ---> 31     strcols = self.fmt.get_strcols()
#      32     if self.fmt.is_truncated:
#      33         strcols = self._insert_dot_separators(strcols)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:540, in DataFrameFormatter.get_strcols(self)
#     536 def get_strcols(self) -> list[list[str]]:
#     537     """
#     538     Render a DataFrame to a list of columns (as lists of strings).
#     539     """
# --> 540     strcols = self._get_strcols_without_index()
#     542     if self.index:
#     543         str_index = self._get_formatted_index(self.tr_frame)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:804, in DataFrameFormatter._get_strcols_without_index(self)
#     800 cheader = str_columns[i]
#     801 header_colwidth = max(
#     802     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     803 )
# --> 804 fmt_values = self.format_col(i)
#     805 fmt_values = _make_fixed_width(
#     806     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     807 )
#     809 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:818, in DataFrameFormatter.format_col(self, i)
#     816 frame = self.tr_frame
#     817 formatter = self._get_formatter(i)
# --> 818 return format_array(
#     819     frame.iloc[:, i]._values,
#     820     formatter,
#     821     float_format=self.float_format,
#     822     na_rep=self.na_rep,
#     823     space=self.col_space.get(frame.columns[i]),
#     824     decimal=self.decimal,
#     825     leading_space=self.index,
#     826 )
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1240, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1225     digits = get_option("display.precision")
#    1227 fmt_obj = fmt_klass(
#    1228     values,
#    1229     digits=digits,
#    (...)
#    1237     quoting=quoting,
#    1238 )
# -> 1240 return fmt_obj.get_result()
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1271, in GenericArrayFormatter.get_result(self)
#    1270 def get_result(self) -> list[str]:
# -> 1271     fmt_values = self._format_strings()
#    1272     return _make_fixed_width(fmt_values, self.justify)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1518, in FloatArrayFormatter._format_strings(self)
#    1517 def _format_strings(self) -> list[str]:
# -> 1518     return list(self.get_result_as_array())
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1502, in FloatArrayFormatter.get_result_as_array(self)
#    1498     abs_vals = np.abs(self.values)
#    1499     # this is pretty arbitrary for now
#    1500     # large values: more that 8 characters including decimal symbol
#    1501     # and first digit, hence > 1e6
# -> 1502     has_large_values = (abs_vals > 1e6).any()
#    1503     has_small_values = (
#    1504         (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
#    1505     ).any()
#    1507 if has_small_values or (too_long and has_large_values):
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/quantity.py:691, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     689     return NotImplemented
#     690 else:
# --> 691     raise e
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/quantity.py:636, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     631 # Determine required conversion functions -- to bring the unit of the
#     632 # input to that expected (e.g., radian for np.sin), or to get
#     633 # consistent units between two inputs (e.g., in np.add) --
#     634 # and the unit of the result (or tuple of units for nout > 1).
#     635 try:
# --> 636     converters, unit = converters_and_unit(function, method, *inputs)
#     638     out = kwargs.get("out", None)
#     639     # Avoid loop back by turning any Quantity output into array views.
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/quantity_helper/converters.py:199, in converters_and_unit(function, method, *args)
#     197             converters[i] = None
#     198         else:
# --> 199             raise UnitConversionError(
#     200                 f"Can only apply '{function.__name__}' function to "
#     201                 "dimensionless quantities when other argument is not "
#     202                 "a quantity (unless the latter is all zero/infinity/nan)."
#     203             )
#     204 except TypeError:
#     205     # _can_have_arbitrary_unit failed: arg could not be compared
#     206     # with zero or checked to be finite. Then, ufunc will fail too.
#     207     raise TypeError(
#     208         "Unsupported operand type(s) for ufunc {}: '{}'".format(
#     209             function.__name__,
#     210             ",".join([arg.__class__.__name__ for arg in args]),
#     211         )
#     212     )
#
# UnitConversionError: Can only apply 'greater' function to dimensionless quantities when other argument is not a quantity (unless the latter is all zero/infinity/nan).
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:1047, in DataFrame._repr_html_(self)
#    1025     show_dimensions = get_option("display.show_dimensions")
#    1027     formatter = fmt.DataFrameFormatter(
#    1028         self,
#    1029         columns=None,
#    (...)
#    1045         decimal=".",
#    1046     )
# -> 1047     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1048 else:
#    1049     return None
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1029, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1020 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1022 html_formatter = Klass(
#    1023     self.fmt,
#    1024     classes=classes,
#    (...)
#    1027     render_links=render_links,
#    1028 )
# -> 1029 string = html_formatter.to_string()
#    1030 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:72, in HTMLFormatter.to_string(self)
#      71 def to_string(self) -> str:
# ---> 72     lines = self.render()
#      73     if any(isinstance(x, str) for x in lines):
#      74         lines = [str(x) for x in lines]
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:621, in NotebookFormatter.render(self)
#     619 self.write("<div>")
#     620 self.write_style()
# --> 621 super().render()
#     622 self.write("</div>")
#     623 return self.elements
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:78, in HTMLFormatter.render(self)
#      77 def render(self) -> list[str]:
# ---> 78     self._write_table()
#      80     if self.should_show_dimensions:
#      81         by = chr(215)  # ×
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:248, in HTMLFormatter._write_table(self, indent)
#     245 if self.fmt.header or self.show_row_idx_names:
#     246     self._write_header(indent + self.indent_delta)
# --> 248 self._write_body(indent + self.indent_delta)
#     250 self.write("</table>", indent)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:395, in HTMLFormatter._write_body(self, indent)
#     393 def _write_body(self, indent: int) -> None:
#     394     self.write("<tbody>", indent)
# --> 395     fmt_values = self._get_formatted_values()
#     397     # write values
#     398     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:585, in NotebookFormatter._get_formatted_values(self)
#     584 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 585     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/html.py:585, in <dictcomp>(.0)
#     584 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 585     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:818, in DataFrameFormatter.format_col(self, i)
#     816 frame = self.tr_frame
#     817 formatter = self._get_formatter(i)
# --> 818 return format_array(
#     819     frame.iloc[:, i]._values,
#     820     formatter,
#     821     float_format=self.float_format,
#     822     na_rep=self.na_rep,
#     823     space=self.col_space.get(frame.columns[i]),
#     824     decimal=self.decimal,
#     825     leading_space=self.index,
#     826 )
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1240, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1225     digits = get_option("display.precision")
#    1227 fmt_obj = fmt_klass(
#    1228     values,
#    1229     digits=digits,
#    (...)
#    1237     quoting=quoting,
#    1238 )
# -> 1240 return fmt_obj.get_result()
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1271, in GenericArrayFormatter.get_result(self)
#    1270 def get_result(self) -> list[str]:
# -> 1271     fmt_values = self._format_strings()
#    1272     return _make_fixed_width(fmt_values, self.justify)
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1518, in FloatArrayFormatter._format_strings(self)
#    1517 def _format_strings(self) -> list[str]:
# -> 1518     return list(self.get_result_as_array())
#
# File /usr/lib/python3/dist-packages/pandas/io/formats/format.py:1502, in FloatArrayFormatter.get_result_as_array(self)
#    1498     abs_vals = np.abs(self.values)
#    1499     # this is pretty arbitrary for now
#    1500     # large values: more that 8 characters including decimal symbol
#    1501     # and first digit, hence > 1e6
# -> 1502     has_large_values = (abs_vals > 1e6).any()
#    1503     has_small_values = (
#    1504         (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
#    1505     ).any()
#    1507 if has_small_values or (too_long and has_large_values):
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/quantity.py:691, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     689     return NotImplemented
#     690 else:
# --> 691     raise e
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/quantity.py:636, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     631 # Determine required conversion functions -- to bring the unit of the
#     632 # input to that expected (e.g., radian for np.sin), or to get
#     633 # consistent units between two inputs (e.g., in np.add) --
#     634 # and the unit of the result (or tuple of units for nout > 1).
#     635 try:
# --> 636     converters, unit = converters_and_unit(function, method, *inputs)
#     638     out = kwargs.get("out", None)
#     639     # Avoid loop back by turning any Quantity output into array views.
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/quantity_helper/converters.py:199, in converters_and_unit(function, method, *args)
#     197             converters[i] = None
#     198         else:
# --> 199             raise UnitConversionError(
#     200                 f"Can only apply '{function.__name__}' function to "
#     201                 "dimensionless quantities when other argument is not "
#     202                 "a quantity (unless the latter is all zero/infinity/nan)."
#     203             )
#     204 except TypeError:
#     205     # _can_have_arbitrary_unit failed: arg could not be compared
#     206     # with zero or checked to be finite. Then, ufunc will fail too.
#     207     raise TypeError(
#     208         "Unsupported operand type(s) for ufunc {}: '{}'".format(
#     209             function.__name__,
#     210             ",".join([arg.__class__.__name__ for arg in args]),
#     211         )
#     212     )
#
# UnitConversionError: Can only apply 'greater' function to dimensionless quantities when other argument is not a quantity (unless the latter is all zero/infinity/nan).
